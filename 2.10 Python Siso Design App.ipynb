# %% [markdown]
# # SISOTOOL no Python
#
# Tentei aqui adaptar rodar o PythonSisoTool dentro do Jupyter, mas ele tem dificuldades em rodar. O autor, Prof. Lucas Bellinaso, sugere rodar no Google Colab, veja abaixo como:
# https://github.com/lucasbellinaso/PythonSisoDesignApp

# %%
try:
  import bokeh
except ImportError:
  # !pip install bokeh

try:
  import control
except ImportError:
  # !pip install control

# !python classes.py             
from classes import SISOApp    
from control.matlab import *

# %% [markdown]
# ## Breve explicação de como funciona

# %%
help(SISOApp)
# Out:
# Help on class SISOApp in module classes:
#
# class SISOApp(builtins.object)
#  |  SISOApp(Gp, Gc=None, Gf=None)
#  |
#  |  Class of SISO Design Python Application
#  |      Control package:   import control.matlab as *
#  |      GUI:  ipywidgets + Bokeh
#  |  Initialization:
#  |      SISOApp(Gp, Gc, Gf)
#  |             Gp: plant transfer function: continuous-time or discrete-time
#  |             Gc (optional): controller transfer function
#  |             Gf (optional - NOT IMPLEMENTED YET): sensor transfer function
#  |
#  |        Control structure of a SISO system:
#  |            r: reference
#  |            u: controller output
#  |            y: process output
#  |            du, dy, dm:  input, output and measurement disturbances
#  |                          du↓+         dy↓+
#  |     r ──→+◯──→[Gc]──u───→+◯──→[Gp]──→+◯──┬──→ y
#  |          -↑                         dm↓+    │
#  |           └────────[Gf]←─────────────◯+←───┘
#  |
# ...

# %% [markdown]
# ## Exemplo de Aplicação
#
# No meu caso, eu preciso ficar rodando (clicando em Play) diversas vezes para ele fazer a interação via BokehJS. Não sei resolver este problema, caso alguém consiga, favor compartilhar, obrigado.

# %%
G = tf([1],[1,1])
SISOApp(G)
# Out:
# AppLayout(children=(HBox(children=(Label(value='Add Pole or Zero:'), Dropdown(description=' ', index=2, option…
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6572">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="d8acdf8b-f4a8-403e-a8c9-104800ecc47d" data-root-id="6376"></div>
